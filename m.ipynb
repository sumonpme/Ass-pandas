# %%
import matplotlib.pyplot as plt
import numpy as np

# Data for the bar chart
x = [20, 30, 40, 50]
y = [100, 200, 300, 400]

# Plotting
plt.title("ODI RUN SUMMARY")  
plt.xlabel("Over")  
plt.ylabel("Run")   

# Plotting the bar chart
plt.bar(x, y, color="green")  
plt.show()
